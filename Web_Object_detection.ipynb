# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics==8.0.54
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.9/496.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train epochs=100 data=/content/drive/MyDrive/Website_Detection/Dataset3/data.yaml model=yolov8m.pt imgsz=448 batch=8
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 139MB/s]
# New https://pypi.org/project/ultralytics/8.0.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.54 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import torch
model = YOLO("/content/runs/detect/train/weights/last.pt","v8")
source ="/content/drive/MyDrive/Website_Detection/1_FXoWPWE-te52R8FJufYjuw.jpg"

output = model.predict(source,save=True,hide_labels = False,line_thickness=1)
# Out:
# image 1/1 /content/drive/MyDrive/Website_Detection/1_FXoWPWE-te52R8FJufYjuw.jpg: 224x448 3 buttons, 7 fields, 1 iframe, 2 labels, 2 texts, 122.4ms
# Speed: 0.5ms preprocess, 122.4ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 448)
# Results saved to runs/detect/predict8
